# %%
# Importamos librerías
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# Lectura y visualización de los datos

# %%
sst_path = 'https://github.com/francobarrionuevoenv21/XArrray_CQSC/raw/refs/heads/main/Data/sst_brasil.nc'
ds_sst = xr.open_dataset(sst_path)
ds_sst
# Out:
# <xarray.Dataset> Size: 70MB
# Dimensions:  (time: 16075, lat: 30, lon: 36)
# Coordinates:
#   * time     (time) datetime64[ns] 129kB 1981-09-01 1981-09-02 ... 2025-09-04
#   * lat      (lat) float32 120B -28.38 -28.12 -27.88 ... -21.62 -21.38 -21.12
#   * lon      (lon) float32 144B 311.1 311.4 311.6 311.9 ... 319.4 319.6 319.9
# Data variables:
#     sst      (time, lat, lon) float32 69MB ...
# Attributes:
#     Conventions:    CF-1.5
#     title:          NOAA High-resolution Blended Analysis: Daily Values using...
#     institution:    NOAA/NCDC
#     source:         NOAA/NCDC  ftp://eclipse.ncdc.noaa.gov/pub/OI-daily-v2/
#     history:        Thu Aug 24 13:34:17 2017: ncatted -O -a References,global...
#     dataset_title:  NOAA Daily Optimum Interpolation Sea Surface Temperature
#     References:     https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2....
#     comment:        Reynolds, et al.(2007) Daily High-Resolution-Blended Anal...

# %%
ds_sst.time
# Out:
# <xarray.DataArray 'time' (time: 16075)> Size: 129kB
# array(['1981-09-01T00:00:00.000000000', '1981-09-02T00:00:00.000000000',
#        '1981-09-03T00:00:00.000000000', ..., '2025-09-02T00:00:00.000000000',
#        '2025-09-03T00:00:00.000000000', '2025-09-04T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 129kB 1981-09-01 1981-09-02 ... 2025-09-04
# Attributes:
#     long_name:     Time
#     delta_t:       0000-00-01 00:00:00
#     avg_period:    0000-00-01 00:00:00
#     axis:          T
#     actual_range:  [66352. 66473.]

# %%
ds_sst.lat
# Out:
# <xarray.DataArray 'lat' (lat: 30)> Size: 120B
# array([-28.375, -28.125, -27.875, -27.625, -27.375, -27.125, -26.875, -26.625,
#        -26.375, -26.125, -25.875, -25.625, -25.375, -25.125, -24.875, -24.625,
#        -24.375, -24.125, -23.875, -23.625, -23.375, -23.125, -22.875, -22.625,
#        -22.375, -22.125, -21.875, -21.625, -21.375, -21.125], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 120B -28.38 -28.12 -27.88 ... -21.62 -21.38 -21.12
# Attributes:
#     long_name:      Latitude
#     standard_name:  latitude
#     units:          degrees_north
#     actual_range:   [-89.875  89.875]
#     axis:           Y

# %%
ds_sst.sst
# Out:
# <xarray.DataArray 'sst' (time: 16075, lat: 30, lon: 36)> Size: 69MB
# [17361000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 129kB 1981-09-01 1981-09-02 ... 2025-09-04
#   * lat      (lat) float32 120B -28.38 -28.12 -27.88 ... -21.62 -21.38 -21.12
#   * lon      (lon) float32 144B 311.1 311.4 311.6 311.9 ... 319.4 319.6 319.9
# Attributes:
#     long_name:     Daily Sea Surface Temperature
#     units:         degC
#     valid_range:   [-3. 45.]
#     precision:     2.0
#     dataset:       NOAA High-resolution Blended Analysis
#     var_desc:      Sea Surface Temperature
#     level_desc:    Surface
#     statistic:     Mean
#     parent_stat:   Individual Observations
#     actual_range:  [-1.8  34.82]

# %%
ds_sst.sst.shape
# Out:
# (16075, 30, 36)

# %%
ds_sst.sst.values
# Out:
# array([[[      nan, 17.58    , 17.77    , ..., 19.84    , 19.789999,
#          19.88    ],
#         [      nan, 17.609999, 17.81    , ..., 20.16    , 20.13    ,
#          20.17    ],
#         [      nan,       nan, 17.97    , ..., 20.43    , 20.41    ,
#          20.439999],
#         ...,
#         [      nan,       nan,       nan, ..., 21.609999, 21.82    ,
#          22.06    ],
#         [      nan,       nan,       nan, ..., 21.539999, 21.73    ,
#          22.01    ],
#         [      nan,       nan,       nan, ..., 21.46    , 21.64    ,
#          21.859999]],
#
#        [[      nan, 17.67    , 17.84    , ..., 19.93    , 19.89    ,
#          19.92    ],
#         [      nan, 17.72    , 17.9     , ..., 20.3     , 20.31    ,
#          20.34    ],
#         [      nan,       nan, 18.06    , ..., 20.619999, 20.63    ,
#          20.66    ],
#         ...,
#         [      nan,       nan,       nan, ..., 21.43    , 21.66    ,
#          21.89    ],
# ...

# %% [markdown]
# Selección y slicing
#
# temporal
#
# espacial

# %%
sst_ds_isel = ds_sst.isel(time=1)

sst_ds_isel.sst.plot(figsize=(5, 3))

# %%
sst_ds_sel = ds_sst.sel(time='1999-05-06')

sst_ds_sel.sst.plot(figsize=(5, 3))

# %%
sst_ds_slice = ds_sst.sel(time=slice('1999-05-06', '1999-05-11'))

sst_ds_slice
#sst_sel.sst.plot()
# Out:
# <xarray.Dataset> Size: 26kB
# Dimensions:  (time: 6, lat: 30, lon: 36)
# Coordinates:
#   * time     (time) datetime64[ns] 48B 1999-05-06 1999-05-07 ... 1999-05-11
#   * lat      (lat) float32 120B -28.38 -28.12 -27.88 ... -21.62 -21.38 -21.12
#   * lon      (lon) float32 144B 311.1 311.4 311.6 311.9 ... 319.4 319.6 319.9
# Data variables:
#     sst      (time, lat, lon) float32 26kB nan 22.54 22.64 ... 25.42 25.64 26.02
# Attributes:
#     Conventions:    CF-1.5
#     title:          NOAA High-resolution Blended Analysis: Daily Values using...
#     institution:    NOAA/NCDC
#     source:         NOAA/NCDC  ftp://eclipse.ncdc.noaa.gov/pub/OI-daily-v2/
#     history:        Thu Aug 24 13:34:17 2017: ncatted -O -a References,global...
#     dataset_title:  NOAA Daily Optimum Interpolation Sea Surface Temperature
#     References:     https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2....
#     comment:        Reynolds, et al.(2007) Daily High-Resolution-Blended Anal...

# %%
fig, ax = plt.subplots(2, 3, figsize=(13, 7), tight_layout=True)
ax = ax.ravel()

for i, d in enumerate(sst_ds_slice.time.values):
    sst_ds_slice['sst'].sel(time=d).plot(ax=ax[i])

# %% [markdown]
# Seleccion espacial

# %%
sst_corr = ds_sst.copy()

# %%
sst_corr['lon'] = sst_corr['lon'] - 360 

print(f'Data original. Lon. mín.: {ds_sst.lon.values.min()}; Lon máx.: {ds_sst.lon.values.max()}')
print(f'Data corregida. Lon. mín.: {sst_corr.lon.values.min()}; Lon máx.: {sst_corr.lon.values.max()}')
# Out:
# Data original. Lon. mín.: 311.125; Lon máx.: 319.875
# Data corregida. Lon. mín.: -48.875; Lon máx.: -40.125

# %% [markdown]
# ver otros metodos de method: https://docs-xarray-dev.translate.goog/en/latest/generated/xarray.DataArray.sel.html?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es&_x_tr_pto=tc#xarray-dataarray-sel
#
# ver dataset.interpolation

# %%
lon_sel, lat_sel = -41, -25

sst_spatial_sel = sst_corr.sel(lon = lon_sel, lat = lat_sel, method = 'nearest')

sst_spatial_sel.sst.plot(figsize=(15, 4))

# %%
lon_min, lon_max = -45, -43
lat_min, lat_max = -25, -23

sst_spatial_slice = sst_corr.sel(lon = slice(lon_min, lon_max), lat = slice(lat_min, lat_max))

sst_spatial_slice.isel(time=1).sst.plot(figsize=(5, 3))

# %% [markdown]
# Rather than using a NumPy-like index selection, in Xarray, we can instead select data based on coordinate values using the .sel() method, which takes one or more named coordinate(s) as a keyword argument:

# %% [markdown]
# Nearest-neighbor Sampling
#
# Suppose we want to know the temperature from 2018-01-07. However, the last day on our time axis is 2018-01-05. We can therefore sample within two days of our desired date of 2018-01-07. We can do this using the .sel() method we used earlier but with the added flexibility of performing nearest neighbor sampling and specifying an optional tolerance. This is called an inexact lookup because we are not searching for a perfect match, although there may be one. Here the tolerance is the maximum distance away from our desired point Xarray will search for the nearest neighbor.

# %% [markdown]
# Operaciónes de agregación
#
# media y desvio espacial
#
# media y desvío temporal
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Operaciónes aritméticas
# cálculo de anomalíaS

# %% [markdown]
# group by

# %%
Series de tiempo

# %%
masking y armado de un mapa de categorias
